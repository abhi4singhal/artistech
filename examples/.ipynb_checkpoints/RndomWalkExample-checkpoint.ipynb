# %%
import os, sys
root_path = os.path.dirname(os.path.dirname(os.path.realpath('.ref')))
sys.path.append(root_path)

# %%
from motion import RandomWalk
from plot import MotionPlot

# %%
MotionPlot().plot(RandomWalk.RandomWalk(500,num_directions=4).get_motion_path())

# %%
MotionPlot().plot(RandomWalk.RandomWalk(500,num_directions=5).get_motion_path())
