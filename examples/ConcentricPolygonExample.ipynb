# %%
import os, sys
root_path = os.path.dirname(os.path.dirname(os.path.realpath('.ref')))
sys.path.append(root_path)

# %%
from shape.Concentric import ConcentricPolygon
from plot import ShapePlot

# %%
ShapePlot(linewidth=1).plot(ConcentricPolygon([3,5,4,3],align=True).get_shapes(),color='white')

# %%
ShapePlot(linewidth=1).plot(ConcentricPolygon([3,5,4,3],separation='irregular').get_shapes(),color='white')

# %%
import numpy as np

# %%
ShapePlot(linewidth=1).plot(ConcentricPolygon(np.random.randint(5,8,12),separation='irregular').get_shapes(),color='white')

# %%
ShapePlot(linewidth=1).plot(ConcentricPolygon(np.random.randint(5,8,30),separation='irregular',min_increase=0.5,max_separation=2).get_shapes(),color='white')

# %%
ShapePlot(linewidth=1).plot(ConcentricPolygon(np.random.randint(5,8,30),separation='irregular',min_increase=0.5,max_separation=2).get_shapes(),color='white')
