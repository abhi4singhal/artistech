# %%
import os, sys
root_path = os.path.dirname(os.path.dirname(os.path.realpath('.ref')))
sys.path.append(root_path)

# %%
from motion import BrownianMotion
from plot import MotionPlot

# %%
MotionPlot().plot(BrownianMotion.BrownianMotion(num_directions=4).get_motion_path(500))

# %%
MotionPlot().plot(BrownianMotion.BrownianMotion(num_directions=5).get_motion_path(500))
